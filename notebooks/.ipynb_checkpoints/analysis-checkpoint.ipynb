# %%
import MetaTrader5 as mt5
import pandas as pd
import datetime
import mplfinance as mpf
import pandas_ta as pta
import numpy as np
from ta.momentum import RSIIndicator
from ta.volatility import AverageTrueRange

if not mt5.initialize():
    print("initialize() failed")
    mt5.shutdown()

# %%
symbol = "ETHUSD"


by_periods = True
if by_periods:
    data = pd.DataFrame(mt5.copy_rates_from_pos(
            symbol,
            mt5.TIMEFRAME_M1,
            0,
            300
        ))
else:
    data = pd.DataFrame(mt5.copy_rates_range(
                symbol,
                mt5.TIMEFRAME_M5,
                datetime.datetime(2023,12,20),
                datetime.datetime(2023,12,20, hour=23, minute=59)
            ))

# rsi indicator configuration
rsi_indicator = RSIIndicator(
            close=data["close"],
            window=5,                   # 14 is default, 9 will give more signals
            )


atr_indicator = AverageTrueRange(
    high=data["high"],
    low=data["low"],
    close=data["close"],
    window=14
)

data["atr"] = round(atr_indicator.average_true_range(), 2)


data.drop(index=len(data)-1, inplace=True)


# create a field converting to local date and time
seven_hours = datetime.timedelta(hours=7)
data = (data
        .assign(server_time = pd.to_datetime(data.time, unit="s").astype(str))
        .assign(time = pd.to_datetime( data.time, unit="s") - seven_hours)
        .assign(local_time = pd.to_datetime( data.time, unit="s") - seven_hours)
        .assign(rsi = rsi_indicator.rsi())
        .set_index("time")
        .sort_index(ascending=False)
        .reset_index()
       )
    
    
# sort ascending for chart
chart_data = data.sort_index( ascending=True)
chart_data.set_index("time", inplace=True)

focus_data = data
focus_data.set_index("time", inplace=True)

# %%
data.head()
# Out:
#                         open     high      low    close  tick_volume  spread  \
# time
# 2024-01-01 11:57:00  2312.13  2312.42  2311.87  2311.95           61     146
# 2024-01-01 11:56:00  2312.33  2312.77  2311.73  2312.13           71     146
# 2024-01-01 11:55:00  2312.91  2312.91  2312.17  2312.36           74     146
# 2024-01-01 11:54:00  2313.23  2313.28  2312.19  2312.91           72     146
# 2024-01-01 11:53:00  2314.08  2314.08  2313.02  2313.23           58     146
#
#                      real_volume   atr          server_time  \
# time
# 2024-01-01 11:57:00            0  1.46  2024-01-01 18:57:00
# 2024-01-01 11:56:00            0  1.54  2024-01-01 18:56:00
# 2024-01-01 11:55:00            0  1.57  2024-01-01 18:55:00
# 2024-01-01 11:54:00            0  1.64  2024-01-01 18:54:00
# 2024-01-01 11:53:00            0  1.68  2024-01-01 18:53:00
#
#                              local_time        rsi
# time
# 2024-01-01 11:57:00 2024-01-01 11:57:00  29.464037
# ...

# %%
data = (data
        .assign(cdl_size = abs(data.high - data.low))
        .assign(cdl_body_size = abs(data.close - data.open))
        .assign(cdl_up = np.where(data.open < data.close, True, False))
        .assign(cdl_down = np.where(data.open > data.close, True, False))
       )

data = (data 
        .assign(cdl_body_perc = data.cdl_body_size / data.cdl_size )
       )

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 299 entries, 2023-12-30 19:10:00 to 2023-12-29 18:10:00
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   open           299 non-null    float64
#  1   high           299 non-null    float64
#  2   low            299 non-null    float64
#  3   close          299 non-null    float64
#  4   tick_volume    299 non-null    uint64
#  5   spread         299 non-null    int32
#  6   real_volume    299 non-null    uint64
#  7   server_time    299 non-null    object
#  8   local_time     299 non-null    datetime64[ns]
#  9   rsi            295 non-null    float64
#  10  cdl_size       299 non-null    float64
#  11  cdl_body_size  299 non-null    float64
#  12  cdl_up         299 non-null    bool
#  13  cdl_down       299 non-null    bool
#  14  cdl_body_perc  299 non-null    float64
# ...

# %%
#if (current_cdl.open <= previous_cdl.close and
#        current_cdl.close >= previous_cdl.open and
#        current_cdl.cdl_up == True and
#        previous_cdl.cdl_up == False and
#        previous_cdl.rsi <= RSI_OVER_SOLD_THRESHOLD
#):
#is_bullish_engulfing = True
previous_cdl = data.shift(-1)


#data = data.assign(prev_cdl_close = data.shift(-1).close)

data["ptn_bullish_engulfing"] = np.where(
            (data.open <= previous_cdl.close) &
            (data.close >= previous_cdl.open) &
            (data.cdl_up & previous_cdl.cdl_down) &
            (previous_cdl.rsi <= 30),
            True, False
        )

# %%
data.query("ptn_bullish_engulfing == True")

#data
#data.head(5)[["open","close", "prev_cdl_close"]]
#print(previous_close)
#print(found)
#data.iloc[[1, 2]]
# Out:
#                         open     high      low    close  tick_volume  spread  \
# time
# 2023-12-30 18:00:00  2288.82  2294.98  2285.42  2293.01          948     146
# 2023-12-30 04:45:00  2270.31  2277.97  2269.61  2277.67          868     146
# 2023-12-30 04:00:00  2274.29  2281.35  2274.22  2280.72          820     146
# 2023-12-30 03:05:00  2294.30  2297.39  2286.31  2297.28          728     146
# 2023-12-30 02:55:00  2295.11  2297.19  2294.89  2297.19          330     146
#
#                      real_volume          server_time          local_time  \
# time
# 2023-12-30 18:00:00            0  2023-12-31 01:00:00 2023-12-30 18:00:00
# 2023-12-30 04:45:00            0  2023-12-30 11:45:00 2023-12-30 04:45:00
# 2023-12-30 04:00:00            0  2023-12-30 11:00:00 2023-12-30 04:00:00
# 2023-12-30 03:05:00            0  2023-12-30 10:05:00 2023-12-30 03:05:00
# 2023-12-30 02:55:00            0  2023-12-30 09:55:00 2023-12-30 02:55:00
#
# ...

# %%
cols = ["local_time", "cdl_body_perc"]
(data
.query("ptn_morning_star == True")
.head(4)[cols]
)
# Out:
# Empty DataFrame
# Columns: [local_time, cdl_body_perc]
# Index: []

# %%
# let's isolate a case where we want to open a trade


focus_data =  data.between_time('2:00', '3:15')

focus_data.assign(signal = np.where( (focus_data.ptn_bullish_engulfing == True), focus_data.close, np.NaN ))

focus_data = focus_data.sort_index(ascending=True)

line30 = np.full( len(focus_data), 30)
line70 = np.full( len(focus_data), 70)


rsi_plot  = [
    mpf.make_addplot(focus_data.rsi, panel=1, ylim=[0,100], ylabel="rsi", type="scatter"),
    mpf.make_addplot(line30, panel=1, width=1),
    mpf.make_addplot(line70, panel=1, width=1),
    mpf.make_addplot(focus_data.signal, type="scatter", marker="$buy$", markersize=800, color="g")
    
]


mpf.plot(focus_data, type="candle", figscale=2.0, addplot=rsi_plot)

# %%
focus_data.query("ptn_bullish_engulfing == True")[["ptn_bullish_engulfing","signal"]]
# Out:
#                      ptn_bullish_engulfing   signal
# time
# 2023-12-30 02:55:00                   True  2297.19
# 2023-12-30 03:05:00                   True  2297.28

# %%
#data["test1"] = test_data.open <= test_data.shift(1).close
#data["test2"] = test_data.close >= test_data.shift(1).open

output_data["prev_close"] = output_data.shift(-1).close
output_data["prev_open"] = output_data.shift(-1).open

output_data.head(2)[["local_time", "open", "close", "test1", "test2", "cdl_bullish_engulfing", "prev_close"]]
# Out:
#                              local_time     open    close  test1  test2  \
# Date
# 2023-12-20 09:40:00 2023-12-20 09:40:00  4762.69  4764.99  False   True
# 2023-12-20 09:35:00 2023-12-20 09:35:00  4759.93  4762.99  False  False
#
#                     cdl_bullish_engulfing  prev_close
# Date
# 2023-12-20 09:40:00                  True     4762.99
# 2023-12-20 09:35:00                  True     4760.23

# %%
# TR = Max of high - low or high - previous close or low - previous close
print("append TR")
data["TR"] = 0
for index, row in data.iterrows():
#    print(row[["local_time"]])   
    data.at[index, "TR"] = max([row.high - row.low, abs(row.high - data.iloc[index-1].close), abs(row.low - data.iloc[index-1].close)]) 




print(data.head(5)[["local_time", "open", "close", "low", "high", "TR"]])

# %%
focus_data["cndl_body_size"] = focus_data["Close"] - focus_data["Open"]
focus_data["cndl_direction"] = focus_data.apply(set_cndl_up_or_down, axis=1)
focus_data
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_16832\2222612621.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   focus_data["cndl_body_size"] = focus_data["Close"] - focus_data["Open"]
# C:\Users\micha\AppData\Local\Temp\ipykernel_16832\2222612621.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   focus_data["cndl_direction"] = focus_data.apply(set_cndl_up_or_down, axis=1)
#                                    time     Open     High      Low    Close  \
# Date
# ...

# %%
# upper case column names because charting library requires it 
chart_data = chart_data.rename(columns={"open": "Open", "close": "Close", "high": "High", "low": "Low", "tick_volume": "Volume"})

mpf.plot(chart_data, type="candle", figscale=2.0)
